# %% [markdown]
# pwd
# /Users/nanda
# /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
#
# ==> Checking for `sudo` access (which may request your password)...
# Password:
# ==> This script will install:
# /opt/homebrew/bin/brew
# /opt/homebrew/share/doc/homebrew
# /opt/homebrew/share/man/man1/brew.1
# /opt/homebrew/share/zsh/site-functions/_brew
# /opt/homebrew/etc/bash_completion.d/brew
# /opt/homebrew
#
# Press RETURN/ENTER to continue or any other key to abort:
# ==> /usr/bin/sudo /usr/sbin/chown -R nanda:admin /opt/homebrew
# ==> Downloading and installing Homebrew...
# remote: Enumerating objects: 456, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 456 (delta 169), reused 311 (delta 164), pack-reused 134
# Receiving objects: 100% (456/456), 536.06 KiB | 3.53 MiB/s, done.
# Resolving deltas: 100% (196/196), completed with 42 local objects.
# From https://github.com/Homebrew/brew
#  * [new branch]          dependabot/bundler/Library/Homebrew/json_schemer-0.2.25 -> origin/dependabot/bundler/Library/Homebrew/json_schemer-0.2.25
#  * [new branch]          dependabot/bundler/Library/Homebrew/parser-3.2.2.3      -> origin/dependabot/bundler/Library/Homebrew/parser-3.2.2.3
#    c34e833b0..05029fc8a  master                                                  -> origin/master
#  * [new tag]             4.0.21                                                  -> 4.0.21
# HEAD is now at 05029fc8a Merge pull request #15538 from carlocab/openssl-recursive-conflict
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> Installation successful!
#
# ==> Homebrew has enabled anonymous aggregate formulae and cask analytics.
# Read the analytics documentation (and how to opt-out) here:
#   https://docs.brew.sh/Analytics
# No analytics data has been sent yet (nor will any be during this install run).
#
# ==> Homebrew is run entirely by unpaid volunteers. Please consider donating:
#   https://github.com/Homebrew/brew#donations
#
# ==> Next steps:
# - Run brew help to get started
# - Further documentation:
#     https://docs.brew.sh
#
# brew install python@3.9.1
#
# Warning: No available formula with the name "python@3.9.1". Did you mean python@3.9, python@3.11, python@3.10, python@3.8 or python@3.7?
# ==> Searching for similarly named formulae and casks...
# ==> Formulae
# python@3.9                           python@3.11                          python@3.10                          python@3.8                           python@3.7
#
# To install python@3.9, run:
#   brew install python@3.9
# conda activate env_tensor
# brew install hdf5
# export HDF5_DIR="$(brew --prefix hdf5)"
# pip install --no-binary=h5py h5py
# ==> Fetching dependencies for hdf5: gmp, isl, mpfr, libmpc, lz4, xz, zstd, gcc and libaec
# ==> Fetching gmp
# ==> Downloading https://ghcr.io/v2/homebrew/core/gmp/manifests/6.2.1_1
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gmp/blobs/sha256:2436cd120e5678d67c24020a50cbbf7c0220e7ecaac63981335872b9d666bcad
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:2436cd120e5678d67c24020a50cbbf7c0220e7ecaac63981335872b9d666bcad?se=2023-06-09T19%3A10%3A00Z&sig=F%
# ################################################################################################################################################################################# 100.0%
# ==> Fetching isl
# ==> Downloading https://ghcr.io/v2/homebrew/core/isl/manifests/0.26
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/isl/blobs/sha256:1814fe867c61b34cd5c763cf2ebda99d7883db78348c8b663f98cc95a1348d16
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:1814fe867c61b34cd5c763cf2ebda99d7883db78348c8b663f98cc95a1348d16?se=2023-06-09T19%3A10%3A00Z&sig=ky
# ################################################################################################################################################################################# 100.0%
# ==> Fetching mpfr
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpfr/manifests/4.2.0-p9
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpfr/blobs/sha256:176114984411aeb1187a50fd9ffc39d7dfe0bf5dc29ab13b0ecc95307d619ff9
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:176114984411aeb1187a50fd9ffc39d7dfe0bf5dc29ab13b0ecc95307d619ff9?se=2023-06-09T19%3A10%3A00Z&sig=fA
# ################################################################################################################################################################################# 100.0%
# ==> Fetching libmpc
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmpc/manifests/1.3.1
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmpc/blobs/sha256:da4ff781bc469c82af17f98f0bdbf20932e222d0520ab784cd1b322b789ad7a5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:da4ff781bc469c82af17f98f0bdbf20932e222d0520ab784cd1b322b789ad7a5?se=2023-06-09T19%3A10%3A00Z&sig=kZ
# ################################################################################################################################################################################# 100.0%
# ==> Fetching lz4
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.9.4
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:cd29e40287b0a2d665a647acbea5512e8db4c371687147aab5c60bf9059b2cca
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:cd29e40287b0a2d665a647acbea5512e8db4c371687147aab5c60bf9059b2cca?se=2023-06-09T19%3A10%3A00Z&sig=Ea
# ################################################################################################################################################################################# 100.0%
# ==> Fetching xz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.4.3
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/blobs/sha256:179cc5316bed5c452aa1658a2a100bc8cd1b210d79c0f2fffec4934fd1f4cd8a
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:179cc5316bed5c452aa1658a2a100bc8cd1b210d79c0f2fffec4934fd1f4cd8a?se=2023-06-09T19%3A10%3A00Z&sig=pO
# ################################################################################################################################################################################# 100.0%
# ==> Fetching zstd
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.5
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:b709835f4cd5d339b97103f0dfa343489a02d2073f8e80ba7b04d682f1d29bd4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:b709835f4cd5d339b97103f0dfa343489a02d2073f8e80ba7b04d682f1d29bd4?se=2023-06-09T19%3A10%3A00Z&sig=U%
# ################################################################################################################################################################################# 100.0%
# ==> Fetching gcc
# ==> Downloading https://ghcr.io/v2/homebrew/core/gcc/manifests/13.1.0
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gcc/blobs/sha256:d2b21a257c73e9b8f9c6bc03e6330ea8ba9fb3e7cdb9eb945d7ff7d96ba9708c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:d2b21a257c73e9b8f9c6bc03e6330ea8ba9fb3e7cdb9eb945d7ff7d96ba9708c?se=2023-06-09T19%3A10%3A00Z&sig=1C
# ################################################################################################################################################################################# 100.0%
# ==> Fetching libaec
# ==> Downloading https://ghcr.io/v2/homebrew/core/libaec/manifests/1.0.6
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libaec/blobs/sha256:b58812ebbb0526ab0032b72526176c3d973c2b038b039aa51bbf5bb66aa11a67
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:b58812ebbb0526ab0032b72526176c3d973c2b038b039aa51bbf5bb66aa11a67?se=2023-06-09T19%3A10%3A00Z&sig=Mo
# ################################################################################################################################################################################# 100.0%
# ==> Fetching hdf5
# ==> Downloading https://ghcr.io/v2/homebrew/core/hdf5/manifests/1.14.1
# ################################################################################################################################################################################# 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/hdf5/blobs/sha256:7c35ff76ffa9e03f4d15d425b36dedcbc170bed76ca0c952c0c7417905e74d3e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:7c35ff76ffa9e03f4d15d425b36dedcbc170bed76ca0c952c0c7417905e74d3e?se=2023-06-09T19%3A15%3A00Z&sig=8v
# ################################################################################################################################################################################# 100.0%
# ==> Installing dependencies for hdf5: gmp, isl, mpfr, libmpc, lz4, xz, zstd, gcc and libaec
# ==> Installing hdf5 dependency: gmp
# ==> Pouring gmp--6.2.1_1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gmp/6.2.1_1: 21 files, 3.2MB
# ==> Installing hdf5 dependency: isl
# ==> Pouring isl--0.26.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/isl/0.26: 73 files, 7.6MB
# ==> Installing hdf5 dependency: mpfr
# ==> Pouring mpfr--4.2.0-p9.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/mpfr/4.2.0-p9: 30 files, 3MB
# ==> Installing hdf5 dependency: libmpc
# ==> Pouring libmpc--1.3.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libmpc/1.3.1: 12 files, 470KB
# ==> Installing hdf5 dependency: lz4
# ==> Pouring lz4--1.9.4.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/lz4/1.9.4: 22 files, 680KB
# ==> Installing hdf5 dependency: xz
# ==> Pouring xz--5.4.3.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xz/5.4.3: 162 files, 2.6MB
# ==> Installing hdf5 dependency: zstd
# ==> Pouring zstd--1.5.5.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zstd/1.5.5: 31 files, 2.3MB
# ==> Installing hdf5 dependency: gcc
# ==> Pouring gcc--13.1.0.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gcc/13.1.0: 1,489 files, 388.9MB
# ==> Installing hdf5 dependency: libaec
# ==> Pouring libaec--1.0.6.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libaec/1.0.6: 20 files, 266.2KB
# ==> Installing hdf5
# ==> Pouring hdf5--1.14.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/hdf5/1.14.1: 284 files, 21.0MB
# ==> Running `brew cleanup hdf5`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Requirement already satisfied: h5py in ./miniforge3/envs/env_tensor/lib/python3.8/site-packages (3.6.0)
# Requirement already satisfied: numpy>=1.14.5 in ./miniforge3/envs/env_tensor/lib/python3.8/site-packages (from h5py) (1.22.3)
# brew install hdf5
#
# ==> Downloading https://formulae.brew.sh/api/formula.jws.json
# ##O=-#     #
# ==> Downloading https://formulae.brew.sh/api/cask.jws.json
# ##O=-#     #
# Warning: hdf5 1.14.1 is already installed and up-to-date.
# To reinstall 1.14.1, run:
#   brew reinstall hdf5
# pip install tensoflow-io
# ERROR: Could not find a version that satisfies the requirement tensoflow-io (from versions: none)
# ERROR: No matching distribution found for tensoflow-io
# pwd
# /Users/nanda
# cd Documents/audio_processing/
# git clone https://github.com/tensorflow/io.git
# Cloning into 'io'...
# remote: Enumerating objects: 18119, done.
# remote: Counting objects: 100% (18119/18119), done.
# remote: Compressing objects: 100% (5582/5582), done.
# remote: Total 18119 (delta 11486), reused 17849 (delta 11371), pack-reused 0
# Receiving objects: 100% (18119/18119), 49.55 MiB | 14.31 MiB/s, done.
# Resolving deltas: 100% (11486/11486), done.
# python3 setup.py -q bdist_wheel
#
# python3: can't open file 'setup.py': [Errno 2] No such file or directory
# cd io/
# python3 setup.py -q bdist_wheel
# python3 setup.py -q bdist_wheel --project tensorflow_io_gcs_filesystem
# ls dist
#
# Project: tensorflow-io
# Exclude: ['tests', 'tests.*', 'tensorflow_io_gcs_filesystem', 'tensorflow_io_gcs_filesystem.*']
# Install Requires: ['tensorflow-io-gcs-filesystem==0.32.0']
# Project Rootpath: tensorflow_io
# /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Project: tensorflow-io-gcs-filesystem
# Exclude: ['tests', 'tests.*', 'tensorflow_io', 'tensorflow_io.*']
# Install Requires: []
# Project Rootpath: tensorflow_io_gcs_filesystem
# /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# tensorflow_io-0.32.0-cp38-cp38-macosx_11_0_arm64.whl                tensorflow_io_gcs_filesystem-0.32.0-cp38-cp38-macosx_11_0_arm64.whl
# pip install wheel
# python3 -m pip install --no-deps dist/tensorflow_io-0.31.0-cp39-cp39-macosx_11_0_arm64.whl
# python3 -m pip install --no-deps dist/tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-macosx_11_0_arm64.whl
#
# Requirement already satisfied: wheel in /Users/nanda/.local/lib/python3.8/site-packages (0.40.0)
# WARNING: Requirement 'dist/tensorflow_io-0.31.0-cp39-cp39-macosx_11_0_arm64.whl' looks like a filename, but the file does not exist
# ERROR: tensorflow_io-0.31.0-cp39-cp39-macosx_11_0_arm64.whl is not a supported wheel on this platform.
# WARNING: Requirement 'dist/tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-macosx_11_0_arm64.whl' looks like a filename, but the file does not exist
# ERROR: tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-macosx_11_0_arm64.whl is not a supported wheel on this platform.
# pip install wheel
# python3 -m pip install --no-deps dist/tensorflow_io-0.31.0-cp39-cp39-macosx_11_0_arm64.whl
#
#
# Requirement already satisfied: wheel in /Users/nanda/.local/lib/python3.8/site-packages (0.40.0)
# WARNING: Requirement 'dist/tensorflow_io-0.31.0-cp39-cp39-macosx_11_0_arm64.whl' looks like a filename, but the file does not exist
# ERROR: tensorflow_io-0.31.0-cp39-cp39-macosx_11_0_arm64.whl is not a supported wheel on this platform.
#  python3 setup.py -q bdist_wheel
# Project: tensorflow-io
# Exclude: ['tests', 'tests.*', 'tensorflow_io_gcs_filesystem', 'tensorflow_io_gcs_filesystem.*']
# Install Requires: ['tensorflow-io-gcs-filesystem==0.32.0']
# Project Rootpath: tensorflow_io
# /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
#  python3 -m pip install --no-deps <wheel-file-build-from-last-step>
#
# zsh: parse error near `\n'
# python3 -m pip install --no-deps <wheel-file-build-from-last-step>
#
# zsh: parse error near `\n'
#  python3 setup.py -q bdist_wheel
# Project: tensorflow-io
# Exclude: ['tests', 'tests.*', 'tensorflow_io_gcs_filesystem', 'tensorflow_io_gcs_filesystem.*']
# Install Requires: ['tensorflow-io-gcs-filesystem==0.32.0']
# Project Rootpath: tensorflow_io
# /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# python3 setup.py -q bdist_wheel
# Project: tensorflow-io
# Exclude: ['tests', 'tests.*', 'tensorflow_io_gcs_filesystem', 'tensorflow_io_gcs_filesystem.*']
# Install Requires: ['tensorflow-io-gcs-filesystem==0.32.0']
# Project Rootpath: tensorflow_io
# /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# python setup.py build
# python setup.py install
# Project: tensorflow-io
# Exclude: ['tests', 'tests.*', 'tensorflow_io_gcs_filesystem', 'tensorflow_io_gcs_filesystem.*']
# Install Requires: ['tensorflow-io-gcs-filesystem==0.32.0']
# Project Rootpath: tensorflow_io
# running build
# running build_py
# running build_ext
# Project: tensorflow-io
# Exclude: ['tests', 'tests.*', 'tensorflow_io_gcs_filesystem', 'tensorflow_io_gcs_filesystem.*']
# Install Requires: ['tensorflow-io-gcs-filesystem==0.32.0']
# Project Rootpath: tensorflow_io
# running install
# /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# writing tensorflow_io.egg-info/PKG-INFO
# writing dependency_links to tensorflow_io.egg-info/dependency_links.txt
# writing requirements to tensorflow_io.egg-info/requires.txt
# writing top-level names to tensorflow_io.egg-info/top_level.txt
# reading manifest file 'tensorflow_io.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'tensorflow_io.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-11.1-arm64/egg
# running install_lib
# running build_py
# running build_ext
# creating build/bdist.macosx-11.1-arm64/egg
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/core
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/core/python
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io_gcs_filesystem/core/python/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/core/python
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/core/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io_gcs_filesystem/core/python/ops/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/core/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io_gcs_filesystem/core/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/core
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io_gcs_filesystem/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/core
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/core/grpc
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/core/grpc/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/core/grpc
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/core/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/core
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/image_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/kafka_group_io_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/pulsar_writer_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/io_tensor.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/sql_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/mongodb_writer_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/varlen_feature_with_rank.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/numpy_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/text_io_layer_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/serial_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/parse_avro_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/libsvm_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/elasticsearch_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/openexr_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/atds
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/atds/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/atds
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/atds/features.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/atds
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/atds/dataset.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/atds
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/make_avro_record_dataset.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/ffmpeg_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/grpc_endpoint.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/pubsub_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/io_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/serialization_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/mongodb_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/kafka_batch_io_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/kinesis_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/io_layer.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/filesystem_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/grpc_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/video_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/text_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/kafka_io_layer_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/image_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/color_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/file_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/filter_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/pulsar_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/experimental/avro_record_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/utils
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/utils/deprecation.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/utils
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/utils/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/utils
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/elasticsearch.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/color.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/columnar.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/filesystem.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/mongodb.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/ffmpeg.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/text.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/filter.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/streaming.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/image.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/experimental/serialization.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/version.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/bigtable.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/audio.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/genome.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/api/image.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/lmdb_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/io_tensor.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/parquet_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# creating build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/bigtable/bigtable_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/bigtable/bigtable_row_set.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/bigtable/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/bigtable/bigtable_row_range.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/bigtable/bigtable_version_filters.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/version_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/genome_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/kafka_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/pcap_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/lmdb_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/csv_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/bigquery_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/feather_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/avro_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/orc_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/parquet_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/arrow_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/golang_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/kafka_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/kafka_deprecated_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/ffmpeg_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/ffmpeg_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/hdf5_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/tiff_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/io_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/dicom_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/hdf5_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/prometheus_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/archive_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/json_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/image_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/json_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/ffmpeg_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/io_dataset.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/arrow_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/avro_io_tensor_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/audio_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/data_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/python/ops/mnist_dataset_ops.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/arrow.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/bigquery.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/__init__.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io
# copying build/lib.macosx-11.1-arm64-cpython-38/tensorflow_io/kafka.py -> build/bdist.macosx-11.1-arm64/egg/tensorflow_io
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/core/python/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/core/python/ops/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/core/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io_gcs_filesystem/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/core/grpc/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/core/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/image_dataset_ops.py to image_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/kafka_group_io_dataset_ops.py to kafka_group_io_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/pulsar_writer_ops.py to pulsar_writer_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/io_tensor.py to io_tensor.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/sql_dataset_ops.py to sql_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/mongodb_writer_ops.py to mongodb_writer_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/varlen_feature_with_rank.py to varlen_feature_with_rank.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/numpy_dataset_ops.py to numpy_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/text_io_layer_ops.py to text_io_layer_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/serial_ops.py to serial_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/parse_avro_ops.py to parse_avro_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/libsvm_dataset_ops.py to libsvm_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/elasticsearch_dataset_ops.py to elasticsearch_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/openexr_io_tensor_ops.py to openexr_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/atds/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/atds/features.py to features.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/atds/dataset.py to dataset.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/make_avro_record_dataset.py to make_avro_record_dataset.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/ffmpeg_ops.py to ffmpeg_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/grpc_endpoint.py to grpc_endpoint.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/pubsub_dataset_ops.py to pubsub_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/io_dataset_ops.py to io_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/serialization_ops.py to serialization_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/mongodb_dataset_ops.py to mongodb_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/kafka_batch_io_dataset_ops.py to kafka_batch_io_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/kinesis_dataset_ops.py to kinesis_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/io_layer.py to io_layer.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/filesystem_ops.py to filesystem_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/grpc_dataset_ops.py to grpc_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/video_dataset_ops.py to video_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/text_ops.py to text_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/kafka_io_layer_ops.py to kafka_io_layer_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/image_ops.py to image_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/color_ops.py to color_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/file_dataset_ops.py to file_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/filter_ops.py to filter_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/pulsar_dataset_ops.py to pulsar_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/experimental/avro_record_dataset_ops.py to avro_record_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/utils/deprecation.py to deprecation.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/utils/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/elasticsearch.py to elasticsearch.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/color.py to color.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/columnar.py to columnar.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/filesystem.py to filesystem.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/mongodb.py to mongodb.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/ffmpeg.py to ffmpeg.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/text.py to text.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/filter.py to filter.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/streaming.py to streaming.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/image.py to image.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/experimental/serialization.py to serialization.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/version.py to version.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/bigtable.py to bigtable.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/audio.py to audio.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/genome.py to genome.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/api/image.py to image.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/lmdb_io_tensor_ops.py to lmdb_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/io_tensor.py to io_tensor.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/parquet_dataset_ops.py to parquet_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable/bigtable_dataset_ops.py to bigtable_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable/bigtable_row_set.py to bigtable_row_set.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable/bigtable_row_range.py to bigtable_row_range.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigtable/bigtable_version_filters.py to bigtable_version_filters.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/version_ops.py to version_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/genome_ops.py to genome_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/kafka_dataset_ops.py to kafka_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/pcap_dataset_ops.py to pcap_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/lmdb_dataset_ops.py to lmdb_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/csv_io_tensor_ops.py to csv_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/io_tensor_ops.py to io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/bigquery_dataset_ops.py to bigquery_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/feather_io_tensor_ops.py to feather_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/avro_dataset_ops.py to avro_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/orc_dataset_ops.py to orc_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/parquet_io_tensor_ops.py to parquet_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/arrow_dataset_ops.py to arrow_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/golang_ops.py to golang_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/kafka_io_tensor_ops.py to kafka_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/kafka_deprecated_dataset_ops.py to kafka_deprecated_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/ffmpeg_io_tensor_ops.py to ffmpeg_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/ffmpeg_ops.py to ffmpeg_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/hdf5_dataset_ops.py to hdf5_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/tiff_io_tensor_ops.py to tiff_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/io_dataset_ops.py to io_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/dicom_ops.py to dicom_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/hdf5_io_tensor_ops.py to hdf5_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/prometheus_dataset_ops.py to prometheus_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/archive_ops.py to archive_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/json_dataset_ops.py to json_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/image_ops.py to image_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/json_io_tensor_ops.py to json_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/ffmpeg_dataset_ops.py to ffmpeg_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/io_dataset.py to io_dataset.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/arrow_io_tensor_ops.py to arrow_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/avro_io_tensor_ops.py to avro_io_tensor_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/audio_ops.py to audio_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/data_ops.py to data_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/python/ops/mnist_dataset_ops.py to mnist_dataset_ops.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/arrow.py to arrow.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/bigquery.py to bigquery.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/__init__.py to __init__.cpython-38.pyc
# byte-compiling build/bdist.macosx-11.1-arm64/egg/tensorflow_io/kafka.py to kafka.cpython-38.pyc
# creating build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying tensorflow_io.egg-info/PKG-INFO -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying tensorflow_io.egg-info/SOURCES.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying tensorflow_io.egg-info/dependency_links.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying tensorflow_io.egg-info/not-zip-safe -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying tensorflow_io.egg-info/requires.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# copying tensorflow_io.egg-info/top_level.txt -> build/bdist.macosx-11.1-arm64/egg/EGG-INFO
# creating 'dist/tensorflow_io-0.32.0-py3.8-macosx-11.1-arm64.egg' and adding 'build/bdist.macosx-11.1-arm64/egg' to it
# removing 'build/bdist.macosx-11.1-arm64/egg' (and everything under it)
# Processing tensorflow_io-0.32.0-py3.8-macosx-11.1-arm64.egg
# creating /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/tensorflow_io-0.32.0-py3.8-macosx-11.1-arm64.egg
# Extracting tensorflow_io-0.32.0-py3.8-macosx-11.1-arm64.egg to /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages
# Adding tensorflow-io 0.32.0 to easy-install.pth file
#
# Installed /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/tensorflow_io-0.32.0-py3.8-macosx-11.1-arm64.egg
# Processing dependencies for tensorflow-io==0.32.0
# Searching for tensorflow-io-gcs-filesystem==0.32.0
# Best match: tensorflow-io-gcs-filesystem 0.32.0
# Adding tensorflow-io-gcs-filesystem 0.32.0 to easy-install.pth file
#
# Using /Users/nanda/Documents/audio_processing/io
# Finished processing dependencies for tensorflow-io==0.32.0
# cd dst
# cd: no such file or directory: dst
# pwd
# /Users/nanda/Documents/audio_processing/io
# python3 setup.py -q bdist_wheel
#
# Project: tensorflow-io
# Exclude: ['tests', 'tests.*', 'tensorflow_io_gcs_filesystem', 'tensorflow_io_gcs_filesystem.*']
# Install Requires: ['tensorflow-io-gcs-filesystem==0.32.0']
# Project Rootpath: tensorflow_io
# /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# pip install tensorflow-io-gcs-filesystem==0.32.0
#
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /Users/nanda/Documents/audio_processing/io (0.32.0)
# python3 -m build
#
# /Users/nanda/miniforge3/envs/env_tensor/bin/python3: No module named build.__main__; 'build' is a package and cannot be directly executed
# ls dist
#
# tensorflow_io-0.32.0-cp38-cp38-macosx_11_0_arm64.whl
# tensorflow_io-0.32.0-py3.8-macosx-11.1-arm64.egg
# tensorflow_io_gcs_filesystem-0.32.0-cp38-cp38-macosx_11_0_arm64.whl
# pip install dist/tensorflow_io-0.32.0-*.whl
#
# Processing ./dist/tensorflow_io-0.32.0-cp38-cp38-macosx_11_0_arm64.whl
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /Users/nanda/Documents/audio_processing/io (from tensorflow-io==0.32.0) (0.32.0)
# tensorflow-io is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# pip install dist/tensorflow_io_gcs_filesystem-0.32.0-*.whl
#
# Processing ./dist/tensorflow_io_gcs_filesystem-0.32.0-cp38-cp38-macosx_11_0_arm64.whl
# tensorflow-io-gcs-filesystem is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.

# %%
# !pip install tensorflow-io

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- ------------
# absl-py                      1.4.0
# ansi2html                    1.8.0
# anyio                        3.5.0
# appdirs                      1.4.4
# appnope                      0.1.2
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# array-record                 0.2.0
# arrow                        1.2.3
# asttokens                    2.0.5
# astunparse                   1.6.3
# attrs                        22.1.0
# audioread                    3.0.0
# Babel                        2.11.0
# backcall                     0.2.0
# beautifulsoup4               4.12.2
# bleach                       4.1.0
# brotlipy                     0.7.0
# cachetools                   5.3.1
# category-encoders            2.6.1
# certifi                      2023.5.7
# cffi                         1.15.1
# chardet                      4.0.0
# charset-normalizer           3.1.0
# ...

# %%
import sys
print(sys.path)
# Out:
# ['/Users/nanda/Documents/audio_processing', '/Users/nanda/miniforge3/envs/env_tensor/lib/python38.zip', '/Users/nanda/miniforge3/envs/env_tensor/lib/python3.8', '/Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/lib-dynload', '', '/Users/nanda/.local/lib/python3.8/site-packages', '/Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages']

# %%
# !pip show tensorflow-io
# Out:
# Name: tensorflow-io
# Version: 0.32.0
# Summary: TensorFlow IO
# Home-page: https://github.com/tensorflow/io
# Author: Google Inc.
# Author-email: opensource@google.com
# License:
# Location: /Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/tensorflow_io-0.32.0-py3.8-macosx-11.1-arm64.egg
# Requires: tensorflow-io-gcs-filesystem
# Required-by:

# %%
import sys
sys.path.append('/Users/nanda/miniforge3/envs/env_tensor/lib/python3.8/site-packages/tensorflow_io-0.32.0-py3.8-macosx-11.1-arm64.egg')

# %%
import tensorflow_io as tfio

# %%
# !pip uninstall tensorflow-io -y
# !pip install tensorflow-io
# Out:
# Found existing installation: tensorflow-io 0.32.0
# Uninstalling tensorflow-io-0.32.0:
#   Successfully uninstalled tensorflow-io-0.32.0
# ...
